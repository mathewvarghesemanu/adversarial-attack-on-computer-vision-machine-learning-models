# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

# NOTE: This is a hack to get around "User-agent" limitations when downloading MNIST datasets
#       see, https://github.com/pytorch/vision/issues/3497 for more information
from six.moves import urllib
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

# %%
epsilons = [0, .05, .1, .15, .2, .25, .3]
pretrained_model = "./model/lenet_mnist_model.pth"
use_cuda=True

# %%
import torch.nn as nn
import torch.nn.functional as F

# LeNet Model definition
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
# MNIST Train dataset and dataloader declaration
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./train_data', train=True, download=True,
                    transform=transforms.ToTensor()),
    batch_size=1, shuffle=True)

# MNIST Test dataset and dataloader declaration
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False, download=True, transform=transforms.Compose([
            transforms.ToTensor(),
            ])),
        batch_size=1, shuffle=True)

# %%
# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

# Initialize the network
model = LeNet5().to(device)

# Load the pretrained model
model.load_state_dict(torch.load(pretrained_model, map_location='cpu'))

# Set the model in evaluation mode. In this case this is for the Dropout layers
model.eval()
# Out:
# CUDA Available:  True
# LeNet5(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    # Return the perturbed image
    return perturbed_image

# %%
def test( model, device, test_loader, epsilon ):

    # Accuracy counter
    correct = 0
    adv_examples = []

    # Loop over all examples in test set
    for data, target in test_loader:

        # Send the data and label to the device
        data, target = data.to(device), target.to(device)

        # Set requires_grad attribute of tensor. Important for Attack
        data.requires_grad = True

        # Forward pass the data through the model
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability

        # If the initial prediction is wrong, dont bother attacking, just move on
        if init_pred.item() != target.item():
            continue

        # Calculate the loss
        loss = F.nll_loss(output, target)

        # Zero all existing gradients
        model.zero_grad()

        # Calculate gradients of model in backward pass
        loss.backward()

        # Collect datagrad
        data_grad = data.grad.data

        # Call FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        if final_pred.item() == target.item():
            correct += 1
            # Special case for saving 0 epsilon examples
            if (epsilon == 0) and (len(adv_examples) < 5):
                adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                adv_examples.append( (init_pred.item(), final_pred.item(), adv_ex) )
        else:
            # Save some adv examples for visualization later
            if len(adv_examples) < 5:
                adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                adv_examples.append( (init_pred.item(), final_pred.item(), adv_ex) )

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader))
    print("Epsilon: {}\tTest Accuracy = {} / {} = {}".format(epsilon, correct, len(test_loader), final_acc))

    # Return the accuracy and an adversarial example
    return final_acc, adv_examples

# %%
accuracies = []
examples = []

# Run test for each epsilon
for eps in epsilons:
    acc, ex = test(model, device, test_loader, eps)
    accuracies.append(acc)
    examples.append(ex)
# Out:
# Epsilon: 0	Test Accuracy = 9810 / 10000 = 0.981
# Epsilon: 0.05	Test Accuracy = 9426 / 10000 = 0.9426
# Epsilon: 0.1	Test Accuracy = 8510 / 10000 = 0.851
# Epsilon: 0.15	Test Accuracy = 6826 / 10000 = 0.6826
# Epsilon: 0.2	Test Accuracy = 4300 / 10000 = 0.43
# Epsilon: 0.25	Test Accuracy = 2082 / 10000 = 0.2082
# Epsilon: 0.3	Test Accuracy = 868 / 10000 = 0.0868

# %%
plt.figure(figsize=(5,5))
plt.plot(epsilons, accuracies, "*-")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.xticks(np.arange(0, .35, step=0.05))
plt.title("Accuracy vs Epsilon")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.show()

# %%
# Plot several examples of adversarial samples at each epsilon
cnt = 0
plt.figure(figsize=(8,10))
for i in range(len(epsilons)):
    for j in range(len(examples[i])):
        cnt += 1
        plt.subplot(len(epsilons),len(examples[0]),cnt)
        plt.xticks([], [])
        plt.yticks([], [])
        if j == 0:
            plt.ylabel("Eps: {}".format(epsilons[i]), fontsize=14)
        orig,adv,ex = examples[i][j]
        plt.title("{} -> {}".format(orig, adv))
        plt.imshow(ex, cmap="gray")
plt.tight_layout()
plt.show()

# %%
# !pip install git+https://github.com/CNOCycle/cleverhans.git@feature/tf2.x
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/CNOCycle/cleverhans.git@feature/tf2.x
#   Cloning https://github.com/CNOCycle/cleverhans.git (to revision feature/tf2.x) to /tmp/pip-req-build-4ivia3ps
#   Running command git clone --filter=blob:none --quiet https://github.com/CNOCycle/cleverhans.git /tmp/pip-req-build-4ivia3ps
#   Running command git checkout -b feature/tf2.x --track origin/feature/tf2.x
#   Switched to a new branch 'feature/tf2.x'
#   Branch 'feature/tf2.x' set up to track remote branch 'feature/tf2.x' from 'origin'.
#   Resolved https://github.com/CNOCycle/cleverhans.git to commit b103b0caf983331ec9c5f7c3e08e417a85bf25e2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nose in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (1.3.7)
# Requirement already satisfied: pycodestyle in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (2.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (1.7.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (3.5.3)
# Requirement already satisfied: mnist~=0.2 in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (1.22.4)
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (0.19.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from cleverhans==3.0.1) (1.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->cleverhans==3.0.1) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->cleverhans==3.0.1) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->cleverhans==3.0.1) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->cleverhans==3.0.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->cleverhans==3.0.1) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->cleverhans==3.0.1) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->cleverhans==3.0.1) (4.38.0)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->cleverhans==3.0.1) (0.4.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->cleverhans==3.0.1) (0.1.8)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->cleverhans==3.0.1) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->cleverhans==3.0.1) (2.2.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->cleverhans==3.0.1) (1.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->cleverhans==3.0.1) (1.15.0)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import warnings
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch import optim
from torch.autograd import Variable
from torchvision import datasets, transforms

from cleverhans.compat import flags
from cleverhans.dataset import MNIST
from cleverhans.utils import AccuracyReport

# %%
from cleverhans.future.torch.attacks.fast_gradient_method import fast_gradient_method

# %%
FLAGS = flags.FLAGS
NB_EPOCHS = 2
BATCH_SIZE = 128
LEARNING_RATE = .001

def trainTorch(torch_model, train_loader, test_loader,
        nb_epochs=NB_EPOCHS, batch_size=BATCH_SIZE, train_end=-1, test_end=-1, learning_rate=LEARNING_RATE, optimizer=None):

    train_loss = []
    total = 0
    correct = 0
    step = 0
    for _epoch in range(nb_epochs):
      for xs, ys in train_loader:
        xs, ys = Variable(xs), Variable(ys)
        if torch.cuda.is_available():
          xs, ys = xs.cuda(), ys.cuda()
        optimizer.zero_grad()
        preds = torch_model(xs)
        loss = F.nll_loss(preds, ys)
        loss.backward()  # calc gradients
        train_loss.append(loss.data.item())
        optimizer.step()  # update gradients

        preds_np = preds.cpu().detach().numpy()
        correct += (np.argmax(preds_np, axis=1) == ys.cpu().detach().numpy()).sum()
        total += train_loader.batch_size
        step += 1
        if total % 1000 == 0:
          acc = float(correct) / total
          print('[%s] Training accuracy: %.2f%%' % (step, acc * 100))
          total = 0
          correct = 0

# %%
#Evaluate results on clean data
def evalClean(model1=None, test_loader=None):
    print("Evaluating single model results on clean data")
    total = 0
    correct = 0
    with torch.no_grad():
      model1.eval()
      for xs, ys in test_loader:
        xs, ys = Variable(xs), Variable(ys)
        if torch.cuda.is_available():
          xs, ys = xs.cuda(), ys.cuda()
        preds1 = model1(xs)
        preds_np1 = preds1.cpu().detach().numpy()
        finalPred = np.argmax(preds_np1, axis=1)
        correct += (finalPred == ys.cpu().detach().numpy()).sum()
        total += len(xs)
    acc = float(correct) / total
    print('Clean accuracy: %.2f%%' % (acc * 100))

#Evaluate results on adversarially perturbed 
def evalAdvAttack(fgsm_model=None, test_loader=None):
    print("Evaluating single model results on adv data")
    total = 0
    correct = 0
    fgsm_model.eval()
    for xs, ys in test_loader:
      if torch.cuda.is_available():
        xs, ys = xs.cuda(), ys.cuda()
      #pytorch fast gradient method
      xs = fast_gradient_method(fgsm_model, xs, eps=0.3, norm=np.inf, clip_min=0., clip_max=1.)
      # xs = fast_gradient_method(fgsm_model, xs, eps=0.1, norm=np.inf)
      xs, ys = Variable(xs), Variable(ys)
      preds1 = fgsm_model(xs)
      preds_np1 = preds1.cpu().detach().numpy()
      finalPred = np.argmax(preds_np1, axis=1)
      correct += (finalPred == ys.cpu().detach().numpy()).sum()
      total += test_loader.batch_size
    acc = float(correct) / total
    print('Adv accuracy: {:.3f}％'.format(acc * 100))

# %%
#Adversarial Training
def advTrain(torch_model, train_loader, test_loader,
        nb_epochs=NB_EPOCHS, batch_size=BATCH_SIZE, train_end=-1, test_end=-1, learning_rate=LEARNING_RATE):
    optimizer = optim.Adam(torch_model.parameters(), lr=learning_rate)
    train_loss = []
    total = 0
    correct = 0
    totalAdv = 0
    correctAdv = 0
    step = 0
    # breakstep = 0
    for _epoch in range(nb_epochs):
      for xs, ys in train_loader:
        #Normal Training
        xs, ys = Variable(xs), Variable(ys)
        if torch.cuda.is_available():
          xs, ys = xs.cuda(), ys.cuda()
        optimizer.zero_grad()
        preds = torch_model(xs)
        loss = F.nll_loss(preds, ys)
        loss.backward()  # calc gradients
        train_loss.append(loss.data.item())
        optimizer.step()  # update gradients
        preds_np = preds.cpu().detach().numpy()
        correct += (np.argmax(preds_np, axis=1) == ys.cpu().detach().numpy()).sum()
        total += train_loader.batch_size

        #Adversarial Training
        xs = fast_gradient_method(torch_model, xs, eps=0.3, norm=np.inf, clip_min=0., clip_max=1.)
        xs, ys = Variable(xs), Variable(ys)
        if torch.cuda.is_available():
            xs, ys = xs.cuda(), ys.cuda()
        optimizer.zero_grad()
        preds = torch_model(xs)
        loss = F.nll_loss(preds, ys)
        loss.backward()  # calc gradients
        train_loss.append(loss.data.item())
        optimizer.step()  # update gradients
        preds_np = preds.cpu().detach().numpy()
        correctAdv += (np.argmax(preds_np, axis=1) == ys.cpu().detach().numpy()).sum()
        totalAdv += train_loader.batch_size
        
        step += 1
        if total % 1000 == 0:
          acc = float(correct) / total
          print('[%s] Clean Training accuracy: %.2f%%' % (step, acc * 100))
          total = 0
          correct = 0
          accAdv = float(correctAdv) / totalAdv
          print('[%s] Adv Training accuracy: %.2f%%' % (step, accAdv * 100))
          totalAdv = 0
          correctAdv = 0

# %%
#Initialize model
model1 = LeNet5()
if torch.cuda.is_available():
  model1 = model1.cuda()
nb_epochs = 4
batch_size = 128
learning_rate = 0.001
train_end = -1
test_end = -1
report = AccuracyReport()

# %%
#Training the model
print("Training Model")
optimizer = optim.Adam(model1.parameters(), lr=learning_rate)
trainTorch(model1, train_loader, test_loader, nb_epochs, batch_size, train_end, test_end, learning_rate, optimizer = optimizer)
# Out:
# Training Model
# [1000] Training accuracy: 36.80%
# [2000] Training accuracy: 67.40%
# [3000] Training accuracy: 74.60%
# [4000] Training accuracy: 77.90%
# [5000] Training accuracy: 83.30%
# [6000] Training accuracy: 81.90%
# [7000] Training accuracy: 85.00%
# [8000] Training accuracy: 86.80%
# [9000] Training accuracy: 86.10%
# [10000] Training accuracy: 87.20%
# [11000] Training accuracy: 90.20%
# [12000] Training accuracy: 88.80%
# [13000] Training accuracy: 87.70%
# [14000] Training accuracy: 88.70%
# [15000] Training accuracy: 88.50%
# [16000] Training accuracy: 88.60%
# [17000] Training accuracy: 89.10%
# [18000] Training accuracy: 88.50%
# [19000] Training accuracy: 89.60%
# [20000] Training accuracy: 88.60%
# [21000] Training accuracy: 89.80%
# [22000] Training accuracy: 88.40%
# [23000] Training accuracy: 90.80%
# [24000] Training accuracy: 87.50%
# [25000] Training accuracy: 90.90%
# [26000] Training accuracy: 91.10%
# [27000] Training accuracy: 90.60%
# [28000] Training accuracy: 89.90%
# [29000] Training accuracy: 91.90%
# [30000] Training accuracy: 89.40%
# [31000] Training accuracy: 92.40%
# [32000] Training accuracy: 91.10%
# [33000] Training accuracy: 91.80%
# [34000] Training accuracy: 90.50%
# [35000] Training accuracy: 91.00%
# [36000] Training accuracy: 91.10%
# [37000] Training accuracy: 92.90%
# [38000] Training accuracy: 90.60%
# [39000] Training accuracy: 90.20%
# [40000] Training accuracy: 92.20%
# [41000] Training accuracy: 93.10%
# [42000] Training accuracy: 91.40%
# [43000] Training accuracy: 92.10%
# [44000] Training accuracy: 90.60%
# [45000] Training accuracy: 92.60%
# [46000] Training accuracy: 92.40%
# [47000] Training accuracy: 91.00%
# [48000] Training accuracy: 91.60%
# [49000] Training accuracy: 92.50%
# [50000] Training accuracy: 91.60%
# [51000] Training accuracy: 91.60%
# [52000] Training accuracy: 91.80%
# [53000] Training accuracy: 92.60%
# [54000] Training accuracy: 92.70%
# [55000] Training accuracy: 90.80%
# [56000] Training accuracy: 90.70%
# [57000] Training accuracy: 93.00%
# [58000] Training accuracy: 91.90%
# [59000] Training accuracy: 92.60%
# [60000] Training accuracy: 92.10%
# [61000] Training accuracy: 92.40%
# [62000] Training accuracy: 91.50%
# [63000] Training accuracy: 91.40%
# [64000] Training accuracy: 93.30%
# [65000] Training accuracy: 93.30%
# [66000] Training accuracy: 92.10%
# [67000] Training accuracy: 90.40%
# [68000] Training accuracy: 93.20%
# [69000] Training accuracy: 92.50%
# [70000] Training accuracy: 92.20%
# [71000] Training accuracy: 93.60%
# [72000] Training accuracy: 94.10%
# [73000] Training accuracy: 92.50%
# [74000] Training accuracy: 90.90%
# [75000] Training accuracy: 92.60%
# [76000] Training accuracy: 92.80%
# [77000] Training accuracy: 93.80%
# [78000] Training accuracy: 94.50%
# [79000] Training accuracy: 92.50%
# [80000] Training accuracy: 94.40%
# [81000] Training accuracy: 92.00%
# [82000] Training accuracy: 92.50%
# [83000] Training accuracy: 92.40%
# [84000] Training accuracy: 94.30%
# [85000] Training accuracy: 93.00%
# [86000] Training accuracy: 92.80%
# [87000] Training accuracy: 93.50%
# [88000] Training accuracy: 94.50%
# [89000] Training accuracy: 91.40%
# [90000] Training accuracy: 94.00%
# [91000] Training accuracy: 93.20%
# [92000] Training accuracy: 93.10%
# [93000] Training accuracy: 90.90%
# [94000] Training accuracy: 92.10%
# [95000] Training accuracy: 93.30%
# [96000] Training accuracy: 91.90%
# [97000] Training accuracy: 92.50%
# [98000] Training accuracy: 93.30%
# [99000] Training accuracy: 92.80%
# [100000] Training accuracy: 92.80%
# [101000] Training accuracy: 90.80%
# [102000] Training accuracy: 92.90%
# [103000] Training accuracy: 94.20%
# [104000] Training accuracy: 91.90%
# [105000] Training accuracy: 91.00%
# [106000] Training accuracy: 93.40%
# [107000] Training accuracy: 90.90%
# [108000] Training accuracy: 92.80%
# [109000] Training accuracy: 93.40%
# [110000] Training accuracy: 91.80%
# [111000] Training accuracy: 93.60%
# [112000] Training accuracy: 91.90%
# [113000] Training accuracy: 93.70%
# [114000] Training accuracy: 93.30%
# [115000] Training accuracy: 93.00%
# [116000] Training accuracy: 92.30%
# [117000] Training accuracy: 91.10%
# [118000] Training accuracy: 92.20%
# [119000] Training accuracy: 94.10%
# [120000] Training accuracy: 93.60%
# [121000] Training accuracy: 92.70%
# [122000] Training accuracy: 91.40%
# [123000] Training accuracy: 90.50%
# [124000] Training accuracy: 94.80%
# [125000] Training accuracy: 91.50%
# [126000] Training accuracy: 93.40%
# [127000] Training accuracy: 91.50%
# [128000] Training accuracy: 93.00%
# [129000] Training accuracy: 91.60%
# [130000] Training accuracy: 92.70%
# [131000] Training accuracy: 92.80%
# [132000] Training accuracy: 91.60%
# [133000] Training accuracy: 93.30%
# [134000] Training accuracy: 92.40%
# [135000] Training accuracy: 90.00%
# [136000] Training accuracy: 94.10%
# [137000] Training accuracy: 93.70%
# [138000] Training accuracy: 93.20%
# [139000] Training accuracy: 91.70%
# [140000] Training accuracy: 92.90%
# [141000] Training accuracy: 92.10%
# [142000] Training accuracy: 92.30%
# [143000] Training accuracy: 92.10%
# [144000] Training accuracy: 92.90%
# [145000] Training accuracy: 93.00%
# [146000] Training accuracy: 95.10%
# [147000] Training accuracy: 94.20%
# [148000] Training accuracy: 92.40%
# [149000] Training accuracy: 92.30%
# [150000] Training accuracy: 92.60%
# [151000] Training accuracy: 92.80%
# [152000] Training accuracy: 93.60%
# [153000] Training accuracy: 93.60%
# [154000] Training accuracy: 93.60%
# [155000] Training accuracy: 91.40%
# [156000] Training accuracy: 92.70%
# [157000] Training accuracy: 93.30%
# [158000] Training accuracy: 91.60%
# [159000] Training accuracy: 91.80%
# [160000] Training accuracy: 92.90%
# [161000] Training accuracy: 92.10%
# [162000] Training accuracy: 92.60%
# [163000] Training accuracy: 91.80%
# [164000] Training accuracy: 92.70%
# [165000] Training accuracy: 93.10%
# [166000] Training accuracy: 92.30%
# [167000] Training accuracy: 93.40%
# [168000] Training accuracy: 91.40%
# [169000] Training accuracy: 91.60%
# [170000] Training accuracy: 91.70%
# [171000] Training accuracy: 91.80%
# [172000] Training accuracy: 92.80%
# [173000] Training accuracy: 91.10%
# [174000] Training accuracy: 92.90%
# [175000] Training accuracy: 93.20%
# [176000] Training accuracy: 91.80%
# [177000] Training accuracy: 93.60%
# [178000] Training accuracy: 93.70%
# [179000] Training accuracy: 92.60%
# [180000] Training accuracy: 91.90%
# [181000] Training accuracy: 92.20%
# [182000] Training accuracy: 94.00%
# [183000] Training accuracy: 93.10%
# [184000] Training accuracy: 94.30%
# [185000] Training accuracy: 92.40%
# [186000] Training accuracy: 94.00%
# [187000] Training accuracy: 92.60%
# [188000] Training accuracy: 92.70%
# [189000] Training accuracy: 92.20%
# [190000] Training accuracy: 92.50%
# [191000] Training accuracy: 90.70%
# [192000] Training accuracy: 93.00%
# [193000] Training accuracy: 92.20%
# [194000] Training accuracy: 92.50%
# [195000] Training accuracy: 92.90%
# [196000] Training accuracy: 92.00%
# [197000] Training accuracy: 93.60%
# [198000] Training accuracy: 91.90%
# [199000] Training accuracy: 92.90%
# [200000] Training accuracy: 92.90%
# [201000] Training accuracy: 91.00%
# [202000] Training accuracy: 93.20%
# [203000] Training accuracy: 92.10%
# [204000] Training accuracy: 92.50%
# [205000] Training accuracy: 92.10%
# [206000] Training accuracy: 92.00%
# [207000] Training accuracy: 93.00%
# [208000] Training accuracy: 92.40%
# [209000] Training accuracy: 90.80%
# [210000] Training accuracy: 93.20%
# [211000] Training accuracy: 92.40%
# [212000] Training accuracy: 91.90%
# [213000] Training accuracy: 90.50%
# [214000] Training accuracy: 93.30%
# [215000] Training accuracy: 92.60%
# [216000] Training accuracy: 92.90%
# [217000] Training accuracy: 92.80%
# [218000] Training accuracy: 92.00%
# [219000] Training accuracy: 92.80%
# [220000] Training accuracy: 93.50%
# [221000] Training accuracy: 92.50%
# [222000] Training accuracy: 92.70%
# [223000] Training accuracy: 92.20%
# [224000] Training accuracy: 89.60%
# [225000] Training accuracy: 92.30%
# [226000] Training accuracy: 92.40%
# [227000] Training accuracy: 91.60%
# [228000] Training accuracy: 92.70%
# [229000] Training accuracy: 92.30%
# [230000] Training accuracy: 91.30%
# [231000] Training accuracy: 90.80%
# [232000] Training accuracy: 93.30%
# [233000] Training accuracy: 92.80%
# [234000] Training accuracy: 92.10%
# [235000] Training accuracy: 91.30%
# [236000] Training accuracy: 91.90%
# [237000] Training accuracy: 91.80%
# [238000] Training accuracy: 92.50%
# [239000] Training accuracy: 93.00%
# [240000] Training accuracy: 93.00%

# %%
#Evaluation
evalClean(model1, test_loader)
evalAdvAttack(model1, test_loader)
# Out:
# Evaluating single model results on clean data
# Clean accuracy: 97.59%
# Evaluating single model results on adv data
# Adv accuracy: 14.980％

# %%
print("Training on Adversarial Samples")
advTrain(model1, train_loader, test_loader, nb_epochs, batch_size, train_end, test_end, learning_rate)
# Out:
# Training on Adversarial Samples
# [1000] Clean Training accuracy: 96.80%
# [1000] Adv Training accuracy: 33.20%
# [2000] Clean Training accuracy: 96.00%
# [2000] Adv Training accuracy: 53.20%
# [3000] Clean Training accuracy: 95.40%
# [3000] Adv Training accuracy: 57.10%
# [4000] Clean Training accuracy: 95.30%
# [4000] Adv Training accuracy: 59.40%
# [5000] Clean Training accuracy: 94.70%
# [5000] Adv Training accuracy: 61.90%
# [6000] Clean Training accuracy: 94.10%
# [6000] Adv Training accuracy: 61.30%
# [7000] Clean Training accuracy: 94.30%
# [7000] Adv Training accuracy: 61.50%
# [8000] Clean Training accuracy: 94.30%
# [8000] Adv Training accuracy: 67.00%
# [9000] Clean Training accuracy: 95.70%
# [9000] Adv Training accuracy: 66.60%
# [10000] Clean Training accuracy: 95.40%
# [10000] Adv Training accuracy: 67.70%
# [11000] Clean Training accuracy: 95.10%
# [11000] Adv Training accuracy: 72.40%
# [12000] Clean Training accuracy: 95.70%
# [12000] Adv Training accuracy: 71.10%
# [13000] Clean Training accuracy: 95.90%
# [13000] Adv Training accuracy: 75.50%
# [14000] Clean Training accuracy: 95.30%
# [14000] Adv Training accuracy: 74.90%
# [15000] Clean Training accuracy: 95.30%
# [15000] Adv Training accuracy: 74.60%
# [16000] Clean Training accuracy: 94.30%
# [16000] Adv Training accuracy: 77.80%
# [17000] Clean Training accuracy: 96.60%
# [17000] Adv Training accuracy: 78.70%
# [18000] Clean Training accuracy: 96.60%
# [18000] Adv Training accuracy: 78.10%
# [19000] Clean Training accuracy: 97.20%
# [19000] Adv Training accuracy: 80.10%
# [20000] Clean Training accuracy: 95.50%
# [20000] Adv Training accuracy: 80.40%
# [21000] Clean Training accuracy: 95.50%
# [21000] Adv Training accuracy: 83.40%
# [22000] Clean Training accuracy: 96.20%
# [22000] Adv Training accuracy: 84.90%
# [23000] Clean Training accuracy: 95.30%
# [23000] Adv Training accuracy: 83.90%
# [24000] Clean Training accuracy: 95.40%
# [24000] Adv Training accuracy: 82.20%
# [25000] Clean Training accuracy: 96.10%
# [25000] Adv Training accuracy: 86.20%
# [26000] Clean Training accuracy: 95.90%
# [26000] Adv Training accuracy: 81.80%
# [27000] Clean Training accuracy: 95.50%
# [27000] Adv Training accuracy: 83.50%
# [28000] Clean Training accuracy: 96.10%
# [28000] Adv Training accuracy: 84.40%
# [29000] Clean Training accuracy: 96.40%
# [29000] Adv Training accuracy: 83.60%
# [30000] Clean Training accuracy: 96.40%
# [30000] Adv Training accuracy: 82.80%
# [31000] Clean Training accuracy: 95.30%
# [31000] Adv Training accuracy: 86.00%
# [32000] Clean Training accuracy: 96.30%
# [32000] Adv Training accuracy: 85.40%
# [33000] Clean Training accuracy: 96.70%
# [33000] Adv Training accuracy: 85.20%
# [34000] Clean Training accuracy: 95.20%
# [34000] Adv Training accuracy: 87.80%
# [35000] Clean Training accuracy: 97.00%
# [35000] Adv Training accuracy: 86.30%
# [36000] Clean Training accuracy: 96.00%
# [36000] Adv Training accuracy: 86.00%
# [37000] Clean Training accuracy: 96.40%
# [37000] Adv Training accuracy: 85.70%
# [38000] Clean Training accuracy: 95.90%
# [38000] Adv Training accuracy: 84.70%
# [39000] Clean Training accuracy: 97.30%
# [39000] Adv Training accuracy: 85.40%
# [40000] Clean Training accuracy: 96.90%
# [40000] Adv Training accuracy: 85.70%
# [41000] Clean Training accuracy: 96.10%
# [41000] Adv Training accuracy: 87.20%
# [42000] Clean Training accuracy: 95.50%
# [42000] Adv Training accuracy: 84.20%
# [43000] Clean Training accuracy: 96.70%
# [43000] Adv Training accuracy: 86.10%
# [44000] Clean Training accuracy: 95.70%
# [44000] Adv Training accuracy: 84.20%
# [45000] Clean Training accuracy: 95.50%
# [45000] Adv Training accuracy: 85.30%
# [46000] Clean Training accuracy: 96.60%
# [46000] Adv Training accuracy: 87.50%
# [47000] Clean Training accuracy: 95.50%
# [47000] Adv Training accuracy: 86.20%
# [48000] Clean Training accuracy: 96.00%
# [48000] Adv Training accuracy: 87.00%
# [49000] Clean Training accuracy: 96.40%
# [49000] Adv Training accuracy: 86.80%
# [50000] Clean Training accuracy: 96.50%
# [50000] Adv Training accuracy: 86.10%
# [51000] Clean Training accuracy: 95.60%
# [51000] Adv Training accuracy: 84.90%
# [52000] Clean Training accuracy: 94.50%
# [52000] Adv Training accuracy: 86.70%
# [53000] Clean Training accuracy: 96.30%
# [53000] Adv Training accuracy: 87.30%
# [54000] Clean Training accuracy: 96.30%
# [54000] Adv Training accuracy: 83.00%
# [55000] Clean Training accuracy: 95.40%
# [55000] Adv Training accuracy: 87.00%
# [56000] Clean Training accuracy: 95.70%
# [56000] Adv Training accuracy: 87.40%
# [57000] Clean Training accuracy: 95.90%
# [57000] Adv Training accuracy: 85.30%
# [58000] Clean Training accuracy: 97.00%
# [58000] Adv Training accuracy: 87.00%
# [59000] Clean Training accuracy: 95.30%
# [59000] Adv Training accuracy: 86.70%
# [60000] Clean Training accuracy: 95.90%
# [60000] Adv Training accuracy: 85.40%
# [61000] Clean Training accuracy: 96.80%
# [61000] Adv Training accuracy: 83.70%
# [62000] Clean Training accuracy: 96.40%
# [62000] Adv Training accuracy: 87.10%
# [63000] Clean Training accuracy: 96.60%
# [63000] Adv Training accuracy: 85.60%
# [64000] Clean Training accuracy: 97.40%
# [64000] Adv Training accuracy: 87.70%
# [65000] Clean Training accuracy: 95.80%
# [65000] Adv Training accuracy: 88.40%
# [66000] Clean Training accuracy: 96.30%
# [66000] Adv Training accuracy: 86.80%
# [67000] Clean Training accuracy: 95.90%
# [67000] Adv Training accuracy: 86.10%
# [68000] Clean Training accuracy: 96.90%
# [68000] Adv Training accuracy: 84.70%
# [69000] Clean Training accuracy: 97.00%
# [69000] Adv Training accuracy: 89.20%
# [70000] Clean Training accuracy: 96.30%
# [70000] Adv Training accuracy: 88.60%
# [71000] Clean Training accuracy: 96.30%
# [71000] Adv Training accuracy: 87.50%
# [72000] Clean Training accuracy: 96.80%
# [72000] Adv Training accuracy: 87.30%
# [73000] Clean Training accuracy: 94.90%
# [73000] Adv Training accuracy: 89.60%
# [74000] Clean Training accuracy: 96.90%
# [74000] Adv Training accuracy: 86.50%
# [75000] Clean Training accuracy: 96.60%
# [75000] Adv Training accuracy: 89.60%
# [76000] Clean Training accuracy: 96.10%
# [76000] Adv Training accuracy: 86.80%
# [77000] Clean Training accuracy: 96.40%
# [77000] Adv Training accuracy: 83.10%
# [78000] Clean Training accuracy: 96.80%
# [78000] Adv Training accuracy: 86.40%
# [79000] Clean Training accuracy: 96.20%
# [79000] Adv Training accuracy: 86.70%
# [80000] Clean Training accuracy: 97.00%
# [80000] Adv Training accuracy: 87.30%
# [81000] Clean Training accuracy: 96.70%
# [81000] Adv Training accuracy: 87.30%
# [82000] Clean Training accuracy: 96.00%
# [82000] Adv Training accuracy: 87.30%
# [83000] Clean Training accuracy: 96.20%
# [83000] Adv Training accuracy: 89.50%
# [84000] Clean Training accuracy: 96.40%
# [84000] Adv Training accuracy: 88.00%
# [85000] Clean Training accuracy: 96.50%
# [85000] Adv Training accuracy: 88.60%
# [86000] Clean Training accuracy: 96.70%
# [86000] Adv Training accuracy: 87.70%
# [87000] Clean Training accuracy: 96.20%
# [87000] Adv Training accuracy: 88.40%
# [88000] Clean Training accuracy: 96.90%
# [88000] Adv Training accuracy: 90.10%
# [89000] Clean Training accuracy: 97.10%
# [89000] Adv Training accuracy: 85.70%
# [90000] Clean Training accuracy: 96.90%
# [90000] Adv Training accuracy: 89.30%
# [91000] Clean Training accuracy: 96.80%
# [91000] Adv Training accuracy: 89.60%
# [92000] Clean Training accuracy: 97.20%
# [92000] Adv Training accuracy: 89.70%
# [93000] Clean Training accuracy: 96.40%
# [93000] Adv Training accuracy: 88.00%
# [94000] Clean Training accuracy: 95.80%
# [94000] Adv Training accuracy: 87.30%
# [95000] Clean Training accuracy: 96.80%
# [95000] Adv Training accuracy: 85.10%
# [96000] Clean Training accuracy: 95.90%
# [96000] Adv Training accuracy: 88.10%
# [97000] Clean Training accuracy: 96.20%
# [97000] Adv Training accuracy: 88.10%
# [98000] Clean Training accuracy: 96.90%
# [98000] Adv Training accuracy: 85.70%
# [99000] Clean Training accuracy: 96.70%
# [99000] Adv Training accuracy: 84.10%
# [100000] Clean Training accuracy: 95.90%
# [100000] Adv Training accuracy: 84.80%
# [101000] Clean Training accuracy: 96.60%
# [101000] Adv Training accuracy: 85.40%
# [102000] Clean Training accuracy: 97.20%
# [102000] Adv Training accuracy: 86.10%
# [103000] Clean Training accuracy: 96.60%
# [103000] Adv Training accuracy: 86.10%
# [104000] Clean Training accuracy: 95.90%
# [104000] Adv Training accuracy: 83.20%
# [105000] Clean Training accuracy: 97.50%
# [105000] Adv Training accuracy: 87.20%
# [106000] Clean Training accuracy: 96.10%
# [106000] Adv Training accuracy: 86.80%
# [107000] Clean Training accuracy: 96.60%
# [107000] Adv Training accuracy: 89.90%
# [108000] Clean Training accuracy: 97.50%
# [108000] Adv Training accuracy: 88.50%
# [109000] Clean Training accuracy: 97.10%
# [109000] Adv Training accuracy: 88.60%
# [110000] Clean Training accuracy: 97.30%
# [110000] Adv Training accuracy: 89.60%
# [111000] Clean Training accuracy: 97.10%
# [111000] Adv Training accuracy: 85.90%
# [112000] Clean Training accuracy: 97.00%
# [112000] Adv Training accuracy: 86.80%
# [113000] Clean Training accuracy: 95.90%
# [113000] Adv Training accuracy: 87.20%
# [114000] Clean Training accuracy: 97.70%
# [114000] Adv Training accuracy: 86.30%
# [115000] Clean Training accuracy: 97.80%
# [115000] Adv Training accuracy: 87.80%
# [116000] Clean Training accuracy: 96.40%
# [116000] Adv Training accuracy: 85.80%
# [117000] Clean Training accuracy: 95.80%
# [117000] Adv Training accuracy: 83.30%
# [118000] Clean Training accuracy: 96.70%
# [118000] Adv Training accuracy: 87.60%
# [119000] Clean Training accuracy: 97.10%
# [119000] Adv Training accuracy: 85.80%
# [120000] Clean Training accuracy: 96.70%
# [120000] Adv Training accuracy: 88.90%
# [121000] Clean Training accuracy: 96.80%
# [121000] Adv Training accuracy: 87.80%
# [122000] Clean Training accuracy: 96.90%
# [122000] Adv Training accuracy: 87.70%
# [123000] Clean Training accuracy: 97.60%
# [123000] Adv Training accuracy: 88.50%
# [124000] Clean Training accuracy: 96.90%
# [124000] Adv Training accuracy: 89.30%
# [125000] Clean Training accuracy: 96.30%
# [125000] Adv Training accuracy: 90.00%
# [126000] Clean Training accuracy: 97.00%
# [126000] Adv Training accuracy: 89.10%
# [127000] Clean Training accuracy: 96.10%
# [127000] Adv Training accuracy: 87.60%
# [128000] Clean Training accuracy: 97.00%
# [128000] Adv Training accuracy: 89.60%
# [129000] Clean Training accuracy: 97.50%
# [129000] Adv Training accuracy: 88.70%
# [130000] Clean Training accuracy: 97.90%
# [130000] Adv Training accuracy: 90.20%
# [131000] Clean Training accuracy: 96.50%
# [131000] Adv Training accuracy: 89.40%
# [132000] Clean Training accuracy: 97.00%
# [132000] Adv Training accuracy: 88.10%
# [133000] Clean Training accuracy: 97.00%
# [133000] Adv Training accuracy: 88.60%
# [134000] Clean Training accuracy: 97.30%
# [134000] Adv Training accuracy: 87.00%
# [135000] Clean Training accuracy: 97.50%
# [135000] Adv Training accuracy: 89.10%
# [136000] Clean Training accuracy: 97.10%
# [136000] Adv Training accuracy: 89.50%
# [137000] Clean Training accuracy: 96.30%
# [137000] Adv Training accuracy: 90.80%
# [138000] Clean Training accuracy: 96.70%
# [138000] Adv Training accuracy: 87.90%
# [139000] Clean Training accuracy: 96.80%
# [139000] Adv Training accuracy: 86.30%
# [140000] Clean Training accuracy: 97.50%
# [140000] Adv Training accuracy: 89.00%
# [141000] Clean Training accuracy: 95.80%
# [141000] Adv Training accuracy: 87.10%
# [142000] Clean Training accuracy: 97.80%
# [142000] Adv Training accuracy: 86.40%
# [143000] Clean Training accuracy: 96.90%
# [143000] Adv Training accuracy: 88.10%
# [144000] Clean Training accuracy: 95.70%
# [144000] Adv Training accuracy: 86.70%
# [145000] Clean Training accuracy: 97.40%
# [145000] Adv Training accuracy: 87.00%
# [146000] Clean Training accuracy: 97.10%
# [146000] Adv Training accuracy: 88.10%
# [147000] Clean Training accuracy: 97.30%
# [147000] Adv Training accuracy: 87.90%
# [148000] Clean Training accuracy: 96.70%
# [148000] Adv Training accuracy: 88.90%
# [149000] Clean Training accuracy: 96.50%
# [149000] Adv Training accuracy: 89.00%
# [150000] Clean Training accuracy: 96.70%
# [150000] Adv Training accuracy: 87.00%
# [151000] Clean Training accuracy: 95.90%
# [151000] Adv Training accuracy: 83.60%
# [152000] Clean Training accuracy: 96.70%
# [152000] Adv Training accuracy: 87.00%
# [153000] Clean Training accuracy: 97.20%
# [153000] Adv Training accuracy: 87.10%
# [154000] Clean Training accuracy: 95.70%
# [154000] Adv Training accuracy: 87.10%
# [155000] Clean Training accuracy: 96.70%
# [155000] Adv Training accuracy: 85.50%
# [156000] Clean Training accuracy: 97.10%
# [156000] Adv Training accuracy: 88.60%
# [157000] Clean Training accuracy: 95.90%
# [157000] Adv Training accuracy: 89.90%
# [158000] Clean Training accuracy: 97.10%
# [158000] Adv Training accuracy: 87.60%
# [159000] Clean Training accuracy: 97.50%
# [159000] Adv Training accuracy: 86.80%
# [160000] Clean Training accuracy: 96.60%
# [160000] Adv Training accuracy: 84.50%
# [161000] Clean Training accuracy: 96.90%
# [161000] Adv Training accuracy: 83.20%
# [162000] Clean Training accuracy: 96.70%
# [162000] Adv Training accuracy: 85.10%
# [163000] Clean Training accuracy: 96.10%
# [163000] Adv Training accuracy: 84.70%
# [164000] Clean Training accuracy: 96.10%
# [164000] Adv Training accuracy: 86.10%
# [165000] Clean Training accuracy: 97.50%
# [165000] Adv Training accuracy: 84.60%
# [166000] Clean Training accuracy: 96.70%
# [166000] Adv Training accuracy: 83.90%
# [167000] Clean Training accuracy: 97.00%
# [167000] Adv Training accuracy: 87.20%
# [168000] Clean Training accuracy: 96.00%
# [168000] Adv Training accuracy: 86.00%
# [169000] Clean Training accuracy: 96.50%
# [169000] Adv Training accuracy: 86.50%
# [170000] Clean Training accuracy: 95.50%
# [170000] Adv Training accuracy: 86.60%
# [171000] Clean Training accuracy: 96.60%
# [171000] Adv Training accuracy: 86.10%
# [172000] Clean Training accuracy: 97.00%
# [172000] Adv Training accuracy: 87.80%
# [173000] Clean Training accuracy: 96.30%
# [173000] Adv Training accuracy: 84.20%
# [174000] Clean Training accuracy: 97.10%
# [174000] Adv Training accuracy: 83.90%
# [175000] Clean Training accuracy: 97.50%
# [175000] Adv Training accuracy: 87.30%
# [176000] Clean Training accuracy: 96.30%
# [176000] Adv Training accuracy: 86.50%
# [177000] Clean Training accuracy: 97.00%
# [177000] Adv Training accuracy: 85.60%
# [178000] Clean Training accuracy: 96.40%
# [178000] Adv Training accuracy: 86.70%
# [179000] Clean Training accuracy: 96.30%
# [179000] Adv Training accuracy: 86.50%
# [180000] Clean Training accuracy: 96.90%
# [180000] Adv Training accuracy: 85.90%
# [181000] Clean Training accuracy: 95.80%
# [181000] Adv Training accuracy: 85.90%
# [182000] Clean Training accuracy: 96.20%
# [182000] Adv Training accuracy: 88.70%
# [183000] Clean Training accuracy: 96.90%
# [183000] Adv Training accuracy: 84.90%
# [184000] Clean Training accuracy: 97.00%
# [184000] Adv Training accuracy: 87.10%
# [185000] Clean Training accuracy: 95.20%
# [185000] Adv Training accuracy: 88.40%
# [186000] Clean Training accuracy: 96.20%
# [186000] Adv Training accuracy: 86.30%
# [187000] Clean Training accuracy: 95.90%
# [187000] Adv Training accuracy: 85.90%
# [188000] Clean Training accuracy: 97.40%
# [188000] Adv Training accuracy: 89.10%
# [189000] Clean Training accuracy: 96.60%
# [189000] Adv Training accuracy: 87.30%
# [190000] Clean Training accuracy: 97.40%
# [190000] Adv Training accuracy: 85.10%
# [191000] Clean Training accuracy: 96.40%
# [191000] Adv Training accuracy: 89.00%
# [192000] Clean Training accuracy: 97.70%
# [192000] Adv Training accuracy: 88.60%
# [193000] Clean Training accuracy: 97.30%
# [193000] Adv Training accuracy: 90.30%
# [194000] Clean Training accuracy: 96.70%
# [194000] Adv Training accuracy: 86.80%
# [195000] Clean Training accuracy: 96.50%
# [195000] Adv Training accuracy: 86.80%
# [196000] Clean Training accuracy: 97.40%
# [196000] Adv Training accuracy: 88.80%
# [197000] Clean Training accuracy: 95.80%
# [197000] Adv Training accuracy: 83.20%
# [198000] Clean Training accuracy: 96.90%
# [198000] Adv Training accuracy: 86.60%
# [199000] Clean Training accuracy: 97.20%
# [199000] Adv Training accuracy: 86.20%
# [200000] Clean Training accuracy: 98.20%
# [200000] Adv Training accuracy: 86.40%
# [201000] Clean Training accuracy: 97.50%
# [201000] Adv Training accuracy: 89.50%
# [202000] Clean Training accuracy: 96.30%
# [202000] Adv Training accuracy: 87.80%
# [203000] Clean Training accuracy: 96.60%
# [203000] Adv Training accuracy: 88.70%
# [204000] Clean Training accuracy: 96.60%
# [204000] Adv Training accuracy: 88.50%
# [205000] Clean Training accuracy: 96.30%
# [205000] Adv Training accuracy: 89.20%
# [206000] Clean Training accuracy: 96.80%
# [206000] Adv Training accuracy: 88.90%
# [207000] Clean Training accuracy: 96.30%
# [207000] Adv Training accuracy: 87.80%
# [208000] Clean Training accuracy: 96.80%
# [208000] Adv Training accuracy: 89.00%
# [209000] Clean Training accuracy: 96.40%
# [209000] Adv Training accuracy: 86.70%
# [210000] Clean Training accuracy: 97.10%
# [210000] Adv Training accuracy: 88.90%
# [211000] Clean Training accuracy: 95.50%
# [211000] Adv Training accuracy: 86.60%
# [212000] Clean Training accuracy: 96.10%
# [212000] Adv Training accuracy: 87.30%
# [213000] Clean Training accuracy: 96.90%
# [213000] Adv Training accuracy: 87.30%
# [214000] Clean Training accuracy: 96.30%
# [214000] Adv Training accuracy: 89.50%
# [215000] Clean Training accuracy: 97.60%
# [215000] Adv Training accuracy: 87.70%
# [216000] Clean Training accuracy: 96.10%
# [216000] Adv Training accuracy: 85.70%
# [217000] Clean Training accuracy: 96.50%
# [217000] Adv Training accuracy: 88.10%
# [218000] Clean Training accuracy: 96.80%
# [218000] Adv Training accuracy: 87.10%
# [219000] Clean Training accuracy: 96.90%
# [219000] Adv Training accuracy: 88.10%
# [220000] Clean Training accuracy: 96.20%
# [220000] Adv Training accuracy: 91.20%
# [221000] Clean Training accuracy: 95.90%
# [221000] Adv Training accuracy: 90.90%
# [222000] Clean Training accuracy: 96.60%
# [222000] Adv Training accuracy: 86.40%
# [223000] Clean Training accuracy: 96.40%
# [223000] Adv Training accuracy: 91.70%
# [224000] Clean Training accuracy: 96.90%
# [224000] Adv Training accuracy: 92.50%
# [225000] Clean Training accuracy: 95.40%
# [225000] Adv Training accuracy: 88.70%
# [226000] Clean Training accuracy: 96.10%
# [226000] Adv Training accuracy: 87.30%
# [227000] Clean Training accuracy: 97.10%
# [227000] Adv Training accuracy: 87.70%
# [228000] Clean Training accuracy: 97.00%
# [228000] Adv Training accuracy: 88.80%
# [229000] Clean Training accuracy: 96.60%
# [229000] Adv Training accuracy: 88.60%
# [230000] Clean Training accuracy: 96.80%
# [230000] Adv Training accuracy: 87.40%
# [231000] Clean Training accuracy: 97.40%
# [231000] Adv Training accuracy: 87.60%
# [232000] Clean Training accuracy: 96.20%
# [232000] Adv Training accuracy: 89.40%
# [233000] Clean Training accuracy: 96.70%
# [233000] Adv Training accuracy: 87.50%
# [234000] Clean Training accuracy: 97.30%
# [234000] Adv Training accuracy: 89.00%
# [235000] Clean Training accuracy: 97.20%
# [235000] Adv Training accuracy: 87.90%
# [236000] Clean Training accuracy: 96.50%
# [236000] Adv Training accuracy: 88.80%
# [237000] Clean Training accuracy: 96.70%
# [237000] Adv Training accuracy: 88.10%
# [238000] Clean Training accuracy: 97.30%
# [238000] Adv Training accuracy: 91.60%
# [239000] Clean Training accuracy: 96.20%
# [239000] Adv Training accuracy: 92.10%
# [240000] Clean Training accuracy: 97.30%
# [240000] Adv Training accuracy: 91.30%

# %%
#Evaluating Again
evalClean(model1, test_loader)
evalAdvAttack(model1, test_loader)
# Out:
# Evaluating single model results on clean data
# Clean accuracy: 96.87%
# Evaluating single model results on adv data
# Adv accuracy: 91.620％
